# %%
# !g++ "D:/STUDY/KTPM/Tuan 1/ConsoleApplication1/ConsoleApplication1/ConsoleApplication1.cpp" -o myprogram
# !myprogram.exe
# Out:
# Test (0, 0, 0) : Infinite solutions.
# Expected: Infinite solutions.
#
# Test (0, 0, 1) : No solution.
# Expected: No solution.
#
# Test (0, 1, 2) : No solution.
# Expected: No solution.
#
# Test (0, 1, -2) : The equation has 2 real solution(s): 1.41421 -1.41421
# Expected: The equation has 2 real solution(s): sqrt(2), -sqrt(2)
#
# Test (1, 1, 1) : No solution.
# Expected: No solution.
#
# Test (1, 0, 0) : The equation has 2 real solution(s): 0 -0
# Expected: The equation has 2 real solution(s): 0, 0
#
# Test (1, 4, 2) : No solution.
# Expected: No solution.
#
# Test (1, -4, 2) : The equation has 4 real solution(s): 1.84776 -1.84776 0.765367 -0.765367
# Expected: The equation has 4 real solution(s): 0.765..., -0.765..., 1.847..., -1.847...
#
# Test (-2, 3, 4) : The equation has 2 real solution(s): 1.53323 -1.53323
# Expected: The equation has 2 real solution(s): 1.533..., -1.533...
#
# Test (1, -2, 1) : The equation has 2 real solution(s): 1 -1
# ...
